# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("../data/cleaned_superstore.csv")

# %%
sales = df["Sales"]

# %%
print("Mean:", sales.mean())
# Out:
# Mean: 92.86485276991051

# %%
print("Median:", sales.median())
# Out:
# Median: 40.88

# %%
print("Mode:", sales.mode()[0])
# Out:
# Mode: 12.96

# %%
print("Standard Deviation:", sales.std())
# Out:
# Standard Deviation: 114.04507757061346

# %%
print("Skewness:", sales.skew())
# Out:
# Skewness: 1.6850350102197391

# %%
group1 = sales.sample(50)
group2 = sales.sample(50)

t, p = stats.ttest_ind(group1, group2)

print("T value:", t)
print("P value:", p)
# Out:
# T value: -1.452620116585421
# P value: 0.14952365592060823

# %% [markdown]
# ## Time Series Analysis

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

df.set_index("Order Date", inplace=True)

monthly = df["Sales"].resample("ME").sum()

monthly.plot(figsize=(10,5))
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
