# %% [markdown]
# # ApexPlanet Data Analytics Internship
# ## Task 1: Foundational Setup & Exploratory Data Analysis (EDA)
#
# **Name:** Bandari Laxmi
# **Dataset:** Sample Superstore Dataset
#
# ### Objectives:
# - Load and understand the dataset
# - Perform data cleaning
# - Handle missing values and duplicates
# - Fix data types
# - Detect and handle outliers
# - Perform Exploratory Data Analysis (EDA)
# - Generate insights from the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("../data/Sample-Superstore.csv")

df.head()
# Out:
#    csvbase_row_id  ﻿Row ID        Order ID  Order Date   Ship Date  \
# 0               1        1  CA-2016-152156  2016-11-08  2016-11-11
# 1               2        2  CA-2016-152156  2016-11-08  2016-11-11
# 2               3        3  CA-2016-138688  2016-06-12  2016-06-16
# 3               4        4  US-2015-108966  2015-10-11  2015-10-18
# 4               5        5  US-2015-108966  2015-10-11  2015-10-18
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Dataset Shape

# %%
df.shape
# Out:
# (9994, 22)

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['csvbase_row_id', '﻿Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='str')

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   csvbase_row_id  9994 non-null   int64
#  1   ﻿Row ID         9994 non-null   int64
#  2   Order ID        9994 non-null   str
#  3   Order Date      9994 non-null   str
#  4   Ship Date       9994 non-null   str
#  5   Ship Mode       9994 non-null   str
#  6   Customer ID     9994 non-null   str
#  7   Customer Name   9994 non-null   str
#  8   Segment         9994 non-null   str
#  9   Country         9994 non-null   str
#  10  City            9994 non-null   str
#  11  State           9994 non-null   str
#  12  Postal Code     9994 non-null   int64
#  13  Region          9994 non-null   str
#  14  Product ID      9994 non-null   str
#  15  Category        9994 non-null   str
#  16  Sub-Category    9994 non-null   str
#  17  Product Name    9994 non-null   str
# ...

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#        csvbase_row_id      ﻿Row ID   Postal Code         Sales     Quantity  \
# count     9994.000000  9994.000000   9994.000000   9994.000000  9994.000000
# mean      4997.500000  4997.500000  55190.379428    229.858001     3.789574
# std       2885.163629  2885.163629  32063.693350    623.245101     2.225110
# min          1.000000     1.000000   1040.000000      0.444000     1.000000
# 25%       2499.250000  2499.250000  23223.000000     17.280000     2.000000
# 50%       4997.500000  4997.500000  56430.500000     54.490000     3.000000
# 75%       7495.750000  7495.750000  90008.000000    209.940000     5.000000
# max       9994.000000  9994.000000  99301.000000  22638.480000    14.000000
#
#           Discount       Profit
# count  9994.000000  9994.000000
# mean      0.156203    28.656896
# std       0.206452   234.260108
# min       0.000000 -6599.978000
# 25%       0.000000     1.728750
# 50%       0.200000     8.666500
# 75%       0.200000    29.364000
# ...

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# csvbase_row_id    0
# ﻿Row ID           0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# # Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Fix Data Types

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   csvbase_row_id  9994 non-null   int64
#  1   ﻿Row ID         9994 non-null   int64
#  2   Order ID        9994 non-null   str
#  3   Order Date      9994 non-null   datetime64[us]
#  4   Ship Date       9994 non-null   datetime64[us]
#  5   Ship Mode       9994 non-null   str
#  6   Customer ID     9994 non-null   str
#  7   Customer Name   9994 non-null   str
#  8   Segment         9994 non-null   str
#  9   Country         9994 non-null   str
#  10  City            9994 non-null   str
#  11  State           9994 non-null   str
#  12  Postal Code     9994 non-null   int64
#  13  Region          9994 non-null   str
#  14  Product ID      9994 non-null   str
#  15  Category        9994 non-null   str
#  16  Sub-Category    9994 non-null   str
#  17  Product Name    9994 non-null   str
# ...

# %% [markdown]
# # Outlier Detection using IQR Method

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['Sales'] >= lower) & (df['Sales'] <= upper)]

print("Outliers removed successfully")
# Out:
# Outliers removed successfully

# %% [markdown]
# # Save Cleaned Dataset

# %%
df.to_csv("../data/cleaned_superstore.csv", index=False)

print("Cleaned dataset saved")
# Out:
# Cleaned dataset saved

# %% [markdown]
# # Histogram: Sales Distribution

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Sales'], bins=30)

plt.title("Sales Distribution")

plt.xlabel("Sales")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Boxplot: Sales

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df['Sales'])

plt.title("Boxplot of Sales")

plt.show()

# %% [markdown]
# # Bar Chart: Sales by Category

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')

plt.title("Sales by Category")

plt.xlabel("Category")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# # Monthly Sales Trend

# %%
monthly_sales = df.groupby(
    df['Order Date'].dt.to_period('M')
)['Sales'].sum()

monthly_sales.plot(figsize=(10,5))

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# # Key Insights
#
# 1. Technology category generated the highest sales among all categories.
#
# 2. Most sales transactions were concentrated in lower sales ranges.
#
# 3. Outliers were identified and removed using the IQR method to improve analysis quality.
#
# 4. Monthly sales showed fluctuations, indicating seasonal trends.
#
# 5. Profit and sales exhibited a positive relationship, suggesting that increased sales generally contributed to higher profits.

# %% [markdown]
# # Conclusion
#
# Task 1 successfully demonstrated the complete process of data cleaning and exploratory data analysis using Python.
#
# The dataset was cleaned, visualized, and analyzed to uncover meaningful business insights that can support data-driven decision-making.
